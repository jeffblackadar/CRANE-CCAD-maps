# %% [markdown]
# <a href="https://colab.research.google.com/github/jeffblackadar/CRANE-CCAD-maps/blob/main/R_Leaflet_map.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # RLeafletMap R6 Class
# Run this before runnign code below.

# %%
library(R6)


RLeafletMap <- R6Class("RLeafletMap",
                  public = list(
                    outputFileHtmlCon = NULL,
                    markers = 0,
                    polylines = 0,
                    layers = 0,

                    initialize = function(outputFileHtmlCon) {
                      self$outputFileHtmlCon <- outputFileHtmlCon
                      self$markers <- 0
                      self$polylines <- 0
                      self$layers <- 0
                    },
                    genMapHTMLTop = function() {
                      writeLines(paste0('<!DOCTYPE html>'), self$outputFileHtmlCon)
                      writeLines(paste0('<html>'), self$outputFileHtmlCon)
                      writeLines(paste0('<head><meta http-equiv="Content-Type" content="text/html; charset=utf-8">'), self$outputFileHtmlCon)
                      writeLines(paste0('<title>map title</title>'), self$outputFileHtmlCon)
                      writeLines(paste0('<link href="https://cdnjs.cloudflare.com/ajax/libs/leaflet/0.7.5/leaflet.css" rel="stylesheet" />'), self$outputFileHtmlCon)
                      writeLines(paste0('<script src="https://cdnjs.cloudflare.com/ajax/libs/leaflet/0.7.5/leaflet.js"></script>'), self$outputFileHtmlCon)
                      writeLines(paste0('<script src="https://code.jquery.com/jquery-2.1.4.min.js"></script>'), self$outputFileHtmlCon)
                      
                      #writeLines(paste0('<script src="//d3js.org/d3.v3.min.js" charset="utf-8"></script>'), self$outputFileHtmlCon)

                      
                      #writeLines(paste0('<script src="https://code.jquery.com/jquery-2.1.4.min.js"></script>'), self$outputFileHtmlCon)                      
                      
                      #writeLines(paste0('<script src="http://octranspo.jeffblackadar.ca/SnakeAnim.js"></script>'), self$outputFileHtmlCon)
                      
                      writeLines(paste0('<style type="text/css">#my-map {'), self$outputFileHtmlCon)
                      writeLines(paste0('  width:960px;'), self$outputFileHtmlCon)
                      writeLines(paste0('  height:700px;'), self$outputFileHtmlCon)
                      writeLines(paste0('}'), self$outputFileHtmlCon)
                      writeLines(paste0('h1 {'), self$outputFileHtmlCon)
                      writeLines(paste0('  color: #AA0000;'), self$outputFileHtmlCon)
                      writeLines(paste0('  font-size: 24px;'), self$outputFileHtmlCon)
                      writeLines(paste0('  font-family: verdana;'), self$outputFileHtmlCon)
                      writeLines(paste0('}'), self$outputFileHtmlCon)
                      writeLines(paste0('h2 {'), self$outputFileHtmlCon)
                      writeLines(paste0('  color: #000000;'), self$outputFileHtmlCon)
                      writeLines(paste0('  font-size: 20px;'), self$outputFileHtmlCon)
                      writeLines(paste0('  font-family: verdana;'), self$outputFileHtmlCon)
                      writeLines(paste0('}'), self$outputFileHtmlCon)
                      writeLines(paste0('h3 {'), self$outputFileHtmlCon)
                      writeLines(paste0('  color: #000000;'), self$outputFileHtmlCon)
                      writeLines(paste0('  font-size: 16px;'), self$outputFileHtmlCon)
                      writeLines(paste0('  font-family: verdana;'), self$outputFileHtmlCon)
                      writeLines(paste0('}'), self$outputFileHtmlCon)    
                      writeLines(paste0('p {'), self$outputFileHtmlCon)
                      writeLines(paste0('  color: #996600;'), self$outputFileHtmlCon)
                      writeLines(paste0('  font-family: verdana;'), self$outputFileHtmlCon)
                      writeLines(paste0('}'), self$outputFileHtmlCon)
                      writeLines(paste0('li {'), self$outputFileHtmlCon)
                      writeLines(paste0('  color: #996600;'), self$outputFileHtmlCon)
                      writeLines(paste0('  font-family: verdana;'), self$outputFileHtmlCon)
                      writeLines(paste0('}'), self$outputFileHtmlCon)  
                      writeLines(paste0('th {'), self$outputFileHtmlCon)
                      writeLines(paste0('  text-align: right;'), self$outputFileHtmlCon)
                      writeLines(paste0('  font-family: verdana;'), self$outputFileHtmlCon)
                      writeLines(paste0('  color: #663300;'), self$outputFileHtmlCon)
                      writeLines(paste0('}'), self$outputFileHtmlCon)
                      writeLines(paste0('td {'), self$outputFileHtmlCon)
                      writeLines(paste0('  text-align: right;'), self$outputFileHtmlCon)
                      writeLines(paste0('  font-family: verdana;'), self$outputFileHtmlCon)
                      writeLines(paste0('  color: #663300;'), self$outputFileHtmlCon)
                      writeLines(paste0('}'), self$outputFileHtmlCon)
                      writeLines(paste0('</style>'), self$outputFileHtmlCon)
                      writeLines(paste0('</head>'), self$outputFileHtmlCon)
                      writeLines(paste0('<body>'), self$outputFileHtmlCon)
                      
                    },

                    genMapHTMLH1 = function(map_title) {  
                      writeLines(paste0('<h1>',map_title,'</h1>'), self$outputFileHtmlCon)
                    },
                    
                    genMapHTMLScriptTop = function() {  
                      
                      writeLines(paste0('  <div id="my-map"></div>'), self$outputFileHtmlCon)
                      writeLines(paste0('    <script>'), self$outputFileHtmlCon)
                      writeLines(paste0('    // This file was generated by this R program:  https://github.com/jeffblackadar/oc-transpo-maps/blob/master/oc_4_gen_html.r'), self$outputFileHtmlCon)
                      writeLines(paste0('  var map;'), self$outputFileHtmlCon)
                    },
                    
                    genMapHTMLMapTop = function() {
                      writeLines("", self$outputFileHtmlCon)
                      writeLines("      map = L.map('my-map');", self$outputFileHtmlCon)
                      writeLines("      //basemap.fitBounds(geojson.getBounds());", self$outputFileHtmlCon)
                      writeLines("      map.setView([45.42, -75.69], 10);", self$outputFileHtmlCon)
                      writeLines("      basemap.addTo(map);", self$outputFileHtmlCon)
                      writeLines("", self$outputFileHtmlCon)      
                      writeLines("      // add legend control layers - global variable with (null, null) allows indiv basemaps and overlays to be added inside functions below", self$outputFileHtmlCon)
                      writeLines("      var controlLayers = L.control.layers(null, null, {", self$outputFileHtmlCon)
                      writeLines('        position: "topleft",', self$outputFileHtmlCon)
                      writeLines("        collapsed: false // false = open by default", self$outputFileHtmlCon)
                      writeLines("      }).addTo(map);", self$outputFileHtmlCon)
                      writeLines("", self$outputFileHtmlCon)   
                    },
                    genHTMLBaseMap = function(){
                      writeLines(paste0('  window.onload = function() {'), self$outputFileHtmlCon)
                      writeLines(paste0("    var basemap = L.tileLayer('http://{s}.tile.osm.org/{z}/{x}/{y}.png', {"), self$outputFileHtmlCon)
                      writeLines(paste0("      attribution: '&copy; ",'<a href="http://osm.org/copyright">OpenStreetMap</a>',"'"), self$outputFileHtmlCon)
                      writeLines(paste0("    });"), self$outputFileHtmlCon)
                      basemapTitle="Open Street Map Today"
                    },
                    genMarker = function(marker_lat, marker_long, marker_text){
                      self$markers <- self$markers +1
                      writeLines(paste0('  var marker',paste0(self$markers),'= L.marker([',paste0(marker_lat),',',paste0(marker_long),']).addTo(map);'), self$outputFileHtmlCon)
                      writeLines(paste0('     marker',paste0(self$markers),".bindPopup('",paste0(marker_text),"').openPopup();"), self$outputFileHtmlCon)
                    },
                    genPolyline = function(p1_lat, p1_long, p2_lat, p2_long){
                      self$polylines <- self$polylines +1
                      writeLines(paste0('  var pointA = new L.LatLng(',paste0(p1_lat),',',paste0(p1_long),' );'), self$outputFileHtmlCon)
                      writeLines(paste0('  var pointB = new L.LatLng(',paste0(p2_lat),',',paste0(p2_long),');'), self$outputFileHtmlCon)
                      writeLines(paste0('  var pointList = [pointA, pointB];'), self$outputFileHtmlCon)
                      writeLines(paste0('  '), self$outputFileHtmlCon)
                      writeLines(paste0('  var polyline',paste0(self$polylines),' = new L.Polyline(pointList, {'), self$outputFileHtmlCon)
                      writeLines(paste0("      color: 'red',"), self$outputFileHtmlCon)
                      writeLines(paste0('      weight: 3,'), self$outputFileHtmlCon)
                      writeLines(paste0('      opacity: 0.5,'), self$outputFileHtmlCon)
                      writeLines(paste0('      smoothFactor: 1'), self$outputFileHtmlCon)
                      writeLines(paste0('  });'), self$outputFileHtmlCon)
                      writeLines(paste0('  polyline',paste0(self$polylines),'.addTo(map);'), self$outputFileHtmlCon)
                    },
                    
                    genSnake = function(){
                      writeLines(paste0(' // Thanks to'), self$outputFileHtmlCon)
                      writeLines(paste0(' // "THE BEER-WARE LICENSE": ivan@sanchezortega.es wrote this file. As long as you retain this notice you can do whatever you want with this stuff. If we meet some day, and you think this stuff is worth it, you can buy me a beer in return.'), self$outputFileHtmlCon)
                      
                      writeLines(paste0('         var route = L.layerGroup(['), self$outputFileHtmlCon)
                      writeLines(paste0('     	L.marker(marker1),'), self$outputFileHtmlCon)
                      writeLines(paste0('     	L.polyline([polyline1, polyline2]),'), self$outputFileHtmlCon)
                      #writeLines(paste0('     	L.marker(airport2)'), self$outputFileHtmlCon)
                      writeLines(paste0('     ], { snakingPause: 200 });'), self$outputFileHtmlCon)
                      writeLines(paste0('     route.addTo(map).snakeIn();'), self$outputFileHtmlCon)
                    },
                    genHTMLEndMap = function(){
                      writeLines(paste0("      controlLayers.addOverlay(basemap, 'basemap title');"), self$outputFileHtmlCon)
                      writeLines(paste0("      "), self$outputFileHtmlCon)
                      writeLines(paste0("   // });"), self$outputFileHtmlCon)
                      writeLines(paste0("  };"), self$outputFileHtmlCon)
                      writeLines(paste0("</script>"), self$outputFileHtmlCon)
                    },
                    genHTMLEndBody = function(){
                      writeLines(paste0("<hr>"), self$outputFileHtmlCon)
                      writeLines(paste0("<p>Page last modifed: ", format(Sys.Date(),"%d %B, %Y"),"</p>"), self$outputFileHtmlCon)
                      writeLines(paste0("</body>"), self$outputFileHtmlCon)
                      writeLines(paste0("</html>"), self$outputFileHtmlCon)
                    },
                    
                    


                   genLayer = function(geojsonfile){
                      self$layers <- self$layers +1
                      #print(paste0("To map for ", railYear, ", adding: "))
                      #print(output_dbRows_route_style[i_route_style, 1])
                      layerName <- paste0("layer", paste0(self$layers))
                      
                      writeLines(paste0(""), self$outputFileHtmlCon)
                      writeLines(paste0("// layer for ",geojsonfile), self$outputFileHtmlCon)
                      writeLines(paste0("var ",layerName,";"), self$outputFileHtmlCon)
                      
                      writeLines(paste0("      $.ajax({"), self$outputFileHtmlCon)
                      writeLines(paste0("        type: 'POST',"), self$outputFileHtmlCon)
                      writeLines(paste0("        url: '",geojsonfile,"',"), self$outputFileHtmlCon)

                      writeLines(paste0("        dataType: 'json',"), self$outputFileHtmlCon)
                      writeLines(paste0("        success: function(response) {"), self$outputFileHtmlCon)
                      writeLines(paste0("          ",layerName," = L.geoJson(response, {"), self$outputFileHtmlCon)
                      
                      writeLines(paste0("             onEachFeature: function (feature, layer) {"), self$outputFileHtmlCon)

                      writeLines(paste0("                 layer.bindPopup('<p>'+feature.properties.RTE_TYPE+'</p><p>'+feature.properties.MODE+'</p>');"), self$outputFileHtmlCon)  
                      
                      writeLines(paste0("               }"), self$outputFileHtmlCon)
                      writeLines(paste0("             });"), self$outputFileHtmlCon)
                      writeLines(paste0("          ",layerName,".setStyle({"), self$outputFileHtmlCon)
                      writeLines(paste0("            color: 'purple',"), self$outputFileHtmlCon)
                      writeLines(paste0("            weight: 2,"), self$outputFileHtmlCon)
                      writeLines(paste0('            opacity: 1'), self$outputFileHtmlCon)
                      writeLines(paste0("          });"), self$outputFileHtmlCon)
                      writeLines(paste0("          ",layerName,".addTo(map);"), self$outputFileHtmlCon)
                      writeLines(paste0("          controlLayers.addOverlay(",layerName,", '<span style=",'"color: purple"',">route</span>');"), self$outputFileHtmlCon)

                      writeLines(paste0("        }"), self$outputFileHtmlCon)
                      writeLines(paste0("      });"), self$outputFileHtmlCon)
                      writeLines(paste0(""), self$outputFileHtmlCon)
                      
                    }



                  )
)

# %% [markdown]
# #Create the map by calling methods of the class.
# This code generates a file called a_test_map.html.  Download it from the Files pane and open it.

# %%
outputFileHtml <- paste0("gardens.html")
outputFileHtmlCon<-file(outputFileHtml, open = "w")
map <- RLeafletMap$new(outputFileHtmlCon=outputFileHtmlCon)
map$genMapHTMLTop()
map$genMapHTMLH1("Pollinator Gardens in District 2, Ontario Horticultural Association")
map$genMapHTMLScriptTop()
map$genHTMLBaseMap()
map$genMapHTMLMapTop()

#map$genMarker(45.3853076228202, -75.7027063624573, '<a href="http://ofnc.ca/programs/fletcher-wildlife-garden">Fletcher Wildlife Garden</a> pollinator garden.')
#map$genMarker(45.2177207,-76.19668383, '<h1>Location: Naismith Public School Pollinator Garden.<h1><h2>Sponsor: Almonte Horticultural Society</h2>')
#map$genMarker(45.6769162,-76.7838167, '<h1>Location: Ross Museum in Forester’s Falls</h1><h2>Sponsor: Beachburg Horticultural Society</h2> <a href="https://www.google.com/maps/dir///@45.6769162,-76.7838167,17z">Directions</a>. Beachburg Horticultural Society partnered with the Ross Museum in Forester’s Falls. Plants are in the Heritage Creek-side garden along with several varieties of shrubs and flowers that attract bees and butterflies. Two bee nests have been installed on a nearby building to provide homes for pollen bees. The Allium bulbs of different sizes and colours we planted will attract visitors and pollen bees. This location is often used as a picnic site and ideal for family photos beside a running stream.')
#map$genMarker(45.1436508,-76.1471922, '<h1>a href="http://www.cpbheritagemuseum.com/">Location: Victoria School Museum gardens</a></h1><h2>Sponsor: Carleton Place Horticultural Society</h2>')
#map$genMarker(45.3853076228202,-75.7027063624573,'<h3><a href="http://ofnc.ca/programs/fletcher-wildlife-garden">Fletcher Wildlife Garden</a></h3><p></p><a href="https://www.google.com/maps/place/Fletcher+Wildlife+Garden/@45.3870864,-75.7053924,17z/data=!3m1!4b1!4m5!3m4!1s0x4cce05d7e1130193:0x20a2dc5c1a64075f!8m2!3d45.3870864!4d-75.7032037">Directions from Google Maps</a>')

map$genMarker(45.2177207,-76.19668383,'<h3>Naismith Public School Pollinator Garden</h3><p>Sponsor: Almonte Horticultural Society</p><p>260 King St, Almonte, ON K0A 1A0<a href="https://www.google.com/maps/place/Naismith+Memorial+Public+School/@45.2177207,-76.1966838,17z/data=!3m1!4b1!4m5!3m4!1s0x4cd21a82b9e49ee7:0x63ecf7f1f28b0063!8m2!3d45.2177207!4d-76.1944951"><br>Directions from Google Maps</a><p>')
map$genMarker(45.6769162,-76.7838167,'<h3>Ross Museum</h3><p>Beachburg Horticultural Society partnered with the Ross Museum in Forester’s Falls. Plants are in the Heritage Creek-side garden along with several varieties of shrubs and flowers that attract bees and butterflies. Two bee nests have been installed on a nearby building to provide homes for pollen bees. The Allium bulbs of different sizes and colours we planted will attract visitors and pollen bees. This location is often used as a picnic site and ideal for family photos beside a running stream.</p><p>2022 Foresters Falls Rd, Foresters Falls, ON K0J 1V0<a href="https://www.google.com/maps/dir///@45.6769162,-76.7838167,17z"><br>Directions from Google Maps</a><p>')
map$genMarker(45.1436508,-76.1471922,'<h3><a href="http://www.cpbheritagemuseum.com/">Victoria School Museum</a></h3><p></p><p>267 Edmund St, Carleton Place, ON K7C 3E8<a href=""><br>Directions from Google Maps</a><p>')
map$genMarker(45.3853076228202,-75.7027063624573,'<h3><a href="http://ofnc.ca/programs/fletcher-wildlife-garden">Fletcher Wildlife Garden</a></h3><p></p><p>near 865, Prince of Wales Dr, Ottawa, ON K2C 3K1<a href="https://www.google.com/maps/place/Fletcher+Wildlife+Garden/@45.3870864,-75.7053924,17z/data=!3m1!4b1!4m5!3m4!1s0x4cce05d7e1130193:0x20a2dc5c1a64075f!8m2!3d45.3870864!4d-75.7032037"><br>Directions from Google Maps</a><p>')
map$genMarker(45.5364896,-77.0975428,'<h3>The Eganville and Area Horticultural Society&apos;s Pollinator Garden</h3><p>The Eganville and Area Horticultural Society&apos;s Pollinator Garden is located on a plot of land generously donated by the township, located adjacent to the Municipal Water Treatment Center at 401 John Street, Eganville. It is clearly marked by a tall Garden Ontario OHA Pollinator Haven sign. Stepping stones inside the garden will help you go through and enjoy the many native species including, chokecherry, bark shrubs, serviceberry trees, cosmos, coneflowers, beebalms, sedums, thyme and asters. The thriving plant life is anchored by 3 pear trees. Pollinators also benefit from aged logs with drilled holes that provide natural bee habitats. Planting began in 2015, and the maturing garden is now abundant, and continues to buzz with activity throughout growing seasons.</p><p>85 John St, Eganville, ON K0J 1T0<a href="https://www.google.com/maps/place/John+Egan+Geo-heritage+Walking+Trail/@45.5364896,-77.0975428,17z/data=!4m12!1m6!3m5!1s0x4cd15eb8d8166041:0x73d40ecc420818ae!2sJohn+Egan+Geo-heritage+Walking+Trail!8m2!3d45.5364671!4d-77.0954829!3m4!1s0x4cd15eb8d8166041:0x73d40ecc420818ae!8m2!3d45.5364671!4d-77.0954829"><br>Directions from Google Maps</a><p>')
#map$genPolyline(45.4376105533903, -75.6575202941895,45.8376105533903, -75.8575202941895)

map$genHTMLEndMap()
map$genHTMLEndBody()

close(outputFileHtmlCon)
